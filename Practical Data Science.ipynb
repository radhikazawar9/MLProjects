# %%
#Author Radhika Zawar s3734939       #
#       Parvi Verma s3744398         #
######################################

#Task 1: Data Preparation
import pandas as pd
from pandas.tools.plotting import scatter_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


#load the data
#reference:(Ren, 2019)
bank = pd.read_csv('bank-additional.csv', sep = ';' , decimal = '.')

#To check the loaded data is equivalent to original data:
##To display the first n observations of dataset
bank.head(10)
##To check the data types of each column 
bank.dtypes
##To display the names of each column
#bank.columns
##To check the size of whole dataset that is (number of observation, number of column)
#bank.shape
#The loaded data is equivalent to original data.
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
########################### White Spaces and Typos ##############################
#To check and remove the white spaces in columns
#reference:(Ren, 2019)
#To generate the frequency table
bank['job'].value_counts()
bank['marital'].value_counts()
bank['education'].value_counts()
bank['default'].value_counts()
bank['housing'].value_counts()
bank['loan'].value_counts()
bank['contact'].value_counts()
bank['month'].value_counts()
bank['day_of_week'].value_counts()
bank['poutcome'].value_counts()
#No white spaces or typos were found.
# Out:
# nonexistent    3523
# failure         454
# success         142
# Name: poutcome, dtype: int64

# %%
########################### Missing Values ##############################
## To find which columns have missing value:
#reference:(Ren, 2019)
bank.isna().sum()
##No missing value found.
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
########################### Impossible Values ##############################
##To check for Impossible Values in data.
## age
bank['age'].value_counts()
bank.loc[bank['age'] < 10]
bank.loc[bank['age'] > 100]
#No Impossible value found
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, housing, loan, contact, month, day_of_week, duration, campaign, pdays, previous, poutcome, emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed, y]
# Index: []
#
# [0 rows x 21 columns]

# %%
####################### Dropping Column ################################3
bank = bank.drop(columns='duration', axis = 1)
bank.columns
# Out:
# Index([u'age', u'job', u'marital', u'education', u'default', u'housing',
#        u'loan', u'contact', u'month', u'day_of_week', u'campaign', u'pdays',
#        u'previous', u'poutcome', u'emp.var.rate', u'cons.price.idx',
#        u'cons.conf.idx', u'euribor3m', u'nr.employed', u'y'],
#       dtype='object')

# %%
##################### Renaming target feature ##########################
bank.rename(columns = {'y':'target_subscribe'}, inplace = True)
bank.columns
# Out:
# Index([u'age', u'job', u'marital', u'education', u'default', u'housing',
#        u'loan', u'contact', u'month', u'day_of_week', u'campaign', u'pdays',
#        u'previous', u'poutcome', u'emp.var.rate', u'cons.price.idx',
#        u'cons.conf.idx', u'euribor3m', u'nr.employed', u'target_subscribe'],
#       dtype='object')

# %%
# Task 2: Data Exploration
# 1) Age
#Histogram is used to show the numerical values of age
bank['age'].plot(kind='hist',bins=20)
#To lable the title of plot
plt.title('PLOT 12-Age Of Customer')
#To label the x axis of plot
plt.xlabel('Age')
#To label the y axis of plot
plt.ylabel('Frequency')
#To display the plot
plt.show()

# %%
# 2) Job
bank['job'].value_counts().plot(kind='bar',title = "PLOT 9-Types Of Job")

# %%
# 3) Marital
#pie chart is used to show the categorical data of martial
bank['marital'].value_counts().plot(kind='pie',autopct='%.2f',figsize=(5,5),title = "PLOT 1-Marital Status")

# %%
# 4) Education
#pie chart is used to show the categorical data of education
bank['education'].value_counts().plot(kind='bar',title = "PLOT 10-Levels of Educational Degrees")

# %%
# 5) Default
#pie chart is used to show the categorical data of default
bank['default'].value_counts().plot(kind='pie',autopct='%.2f',figsize=(5,5),title = "PLOT 2-Credit in Default")

# %%
# 6) Housing
#pie chart is used to show the categorical data of housing
bank['housing'].value_counts().plot(kind='pie',autopct='%.2f',figsize=(5,5),title = "PLOT 3-Housing Loan Status")

# %%
# 7) Loan
#pie chart is used to show the categorical data of loan
bank['loan'].value_counts().plot(kind='pie',autopct='%.2f',figsize=(5,5),title = "PLOT 4-Personal Loan Status")

# %%
# 8) Contact
#pie chart is used to show the categorical data of contact
bank['contact'].value_counts().plot(kind='pie',autopct='%.2f',figsize=(5,5),title = "PLOT 5-Type of Communication Contact")

# %%
# 9) Month
#bar chart is used to show the categorical data of month
bank['month'].value_counts().plot(kind='bar',title = "PLOT 11-Last contact Month")

# %%
# 10) day_of_week
#pie chart is used to show the categorical data of day_of_week
bank['day_of_week'].value_counts().plot(kind='pie',autopct='%.2f',figsize=(5,5),title = "PLOT 6-Last Contact Day Of Week")

# %%
# 11) Campaign
#Histogram is used to show the numerical values of Campaign
bank['campaign'].plot(kind='hist',bins=20, xlim = (0,20))
#To lable the title of plot
plt.title('PLOT 13-Contacts performed during this Campaign')
#To label the x axis of plot
plt.xlabel('campaign')
#To label the y axis of plot
plt.ylabel('Frequency')
#To display the plot
plt.show()

# %%
# 12) pdays
#Histogram is used to show the numerical values of pdays
bank['pdays'].plot(kind='hist',bins=5)
#To lable the title of plot
plt.title('PLOT 14-Days passed after last Contact')
#To label the x axis of plot
plt.xlabel('Passed-Days')
#To label the y axis of plot
plt.ylabel('Frequency')
#To display the plot
plt.show()

# %%
# 13) previous
#Histogram is used to show the numerical values of duration
bank['previous'].plot(kind='hist',bins=15)
#To lable the title of plot
plt.title('PLOT 15-No. of contacts before this Campaign')
#To label the x axis of plot
plt.xlabel('No. of contacts')
#To label the y axis of plot
plt.ylabel('Frequency')
#To display the plot
plt.show()

# %%
# 14) poutcome
#pie chart is used to show the categorical data of poutcome
bank['poutcome'].value_counts().plot(kind='pie',autopct='%.2f',figsize=(5,5),title = "PLOT 7-Outcome of previous campaign")

# %%
# 15) emp.var.rate
#Histogram is used to show the numerical values of duration
bank['emp.var.rate'].plot(kind='hist',bins=15)
#To lable the title of plot
plt.title('PLOT 16-Days passed after last Contact')
#To label the x axis of plot
plt.xlabel('Passed-Days')
#To label the y axis of plot
plt.ylabel('Frequency')
#To display the plot
plt.show()

# %%
# 16) cons.price.idx
#Histogram is used to show the numerical values of duration
bank['cons.price.idx'].plot(kind='hist',bins=15)
#To lable the title of plot
plt.title('PLOT 17-Days passed after last Contact')
#To label the x axis of plot
plt.xlabel('Passed-Days')
#To label the y axis of plot
plt.ylabel('Frequency')
#To display the plot
plt.show()

# %%
# 17) cons.conf.idx
#Histogram is used to show the numerical values of duration
bank['cons.conf.idx'].plot(kind='hist',bins=15)
#To lable the title of plot
plt.title('PLOT 18-Days passed after last Contact')
#To label the x axis of plot
plt.xlabel('Passed-Days')
#To label the y axis of plot
plt.ylabel('Frequency')
#To display the plot
plt.show()

# %%
# 18) euribor3m
#Histogram is used to show the numerical values of duration
bank['euribor3m'].plot(kind='hist',bins=15)
#To lable the title of plot
plt.title('PLOT 19-Days passed after last Contact')
#To label the x axis of plot
plt.xlabel('Passed-Days')
#To label the y axis of plot
plt.ylabel('Frequency')
#To display the plot
plt.show()

# %%
# 19) nr.employed
#Histogram is used to show the numerical values of duration
bank['nr.employed'].plot(kind='hist',bins=5)
#To lable the title of plot
plt.title('PLOT 20-Days passed after last Contact')
#To label the x axis of plot
plt.xlabel('Passed-Days')
#To label the y axis of plot
plt.ylabel('Frequency')
#To display the plot
plt.show()

# %%
# 20) target_subscribe
#pie chart is used to show the categorical data of target_subscribe
bank['target_subscribe'].value_counts().plot(kind='pie',autopct='%.2f',figsize=(5,5),title = "PLOT 8-Subscription")

# %%
## Bivariate Analysis

# 1) age vs target_subscribe
sns.boxplot(x = 'target_subscribe', y = 'age', data = bank)
plt.show()
# 2) campaign vs target_subscribe
sns.boxplot(x = 'target_subscribe', y = 'campaign', data = bank)
plt.show()
# 3) emp.var.rate vs target_subscribe
sns.boxplot(x = 'target_subscribe', y = 'emp.var.rate', data = bank)
plt.show()
# 4) cons.price.idx vs target_subscribe
sns.boxplot(x = 'target_subscribe', y = 'cons.price.idx', data = bank)
plt.show()
# 5) euribor3m vs target_subscribe
sns.boxplot(x = 'target_subscribe', y = 'euribor3m', data = bank)
plt.show()
# 6) nr.employed vs target_subscribe
sns.boxplot(x = 'target_subscribe', y = 'nr.employed', data = bank)
plt.show()

# %%
# 7) job vs target_subscribe

jobs = bank['job'].value_counts()
m_height = jobs.values.tolist()
jobs.axes 
jobs_labels = jobs.axes[0].tolist() 
yes_cc = [] #yes Subscription list
no_cc = []    #no Subscription list
for x in jobs_labels:
    size = len(bank[bank['job'] == x].index)
    subs = len(bank[(bank['job'] == x) & (bank['target_subscribe'] == 'yes')].index)
    yes_cc.append(subs)
    no_cc.append(size-subs)
                        
ind = np.arange(12) 
width = 0.40
fig, ax = plt.subplots(figsize=(12,7))
yes_bars = ax.bar(ind, yes_cc , width, color='#ADFF2F')
no_bars = ax.bar(ind+width, no_cc , width, color='#DA70D6')


ax.set_xlabel("Types Of Jobs",fontsize=20)
ax.set_ylabel('Frequency',fontsize=20)
ax.set_title('PLOT 1-Subscription Based on Job Type',fontsize=22)
ax.set_xticks(ind + width / 2) 
ax.set_xticklabels(('admin', 'blue-collar','technician','services','  management','retired','  self-employed','  entrepreneur','unemployed','housemaid','student','unknown'),
                  fontsize = 12)
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
ax.legend((yes_bars,no_bars),('yes','no'),fontsize=17)

def autolabel(rects,fontsize=14):
    
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1*height,'%d' % int(height),
                ha='center', va='bottom',fontsize=fontsize)        
autolabel(yes_bars, 10)
autolabel(no_bars, 10)
plt.show()
print(yes_cc)
print(no_cc)
# Out:
# [133, 61, 80, 35, 30, 38, 13, 8, 19, 11, 19, 4]
# [879, 823, 611, 358, 294, 128, 146, 140, 92, 99, 63, 35]

# %%
# 8) marital vs target_subscribe

mari = bank['marital'].value_counts()
m_height = mari.values.tolist() 
mari.axes #Provides row labels
mari_labels = mari.axes[0].tolist()

yes_cc = [] #yes Subscription list
no_cc = []    #no Subscription list
for x in mari_labels:
    size = len(bank[bank['marital'] == x].index)
    subs = len(bank[(bank['marital'] == x) & (bank['target_subscribe'] == 'yes')].index)
    yes_cc.append(subs)
    no_cc.append(size-subs)
                        

ind = np.arange(4) 
width = 0.20
fig, ax = plt.subplots(figsize=(12,7))
yes_bars = ax.bar(ind, yes_cc , width, color='orange')
no_bars = ax.bar(ind+width, no_cc , width, color='#ADFF2F')


ax.set_xlabel("Types Of Marital Status",fontsize=20)
ax.set_ylabel('Frequency',fontsize=20)
ax.set_title('PLOT 2-Subscription Based on Marital Status',fontsize=22)
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(('married', 'single','  divorced','unknown'),
                  fontsize = 12)
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
ax.legend((yes_bars,no_bars),('yes','no'),fontsize=17)

def autolabel(rects,fontsize=14):
    
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1*height,'%d' % int(height),
                ha='center', va='bottom',fontsize=fontsize)        
autolabel(yes_bars, 10)
autolabel(no_bars, 10)
plt.show()
print(yes_cc)
print(no_cc)
# Out:
# [252, 155, 43, 1]
# [2257, 998, 403, 10]

# %%
# 9) education vs target_subscribe

edu = bank['education'].value_counts()
m_height = edu.values.tolist() 
edu.axes
edu_labels = edu.axes[0].tolist() 

yes_cc = [] #yes Subscription list
no_cc = []    #no Subscription list
for x in edu_labels:
    size = len(bank[bank['education'] == x].index)
    subs = len(bank[(bank['education'] == x) & (bank['target_subscribe'] == 'yes')].index)
    yes_cc.append(subs)
    no_cc.append(size-subs)
                        

ind = np.arange(8) 
width = 0.40
fig, ax = plt.subplots(figsize=(12,7))
yes_bars = ax.bar(ind, yes_cc , width, color='orange')
no_bars = ax.bar(ind+width, no_cc , width, color='#DA70D6')


ax.set_xlabel("Types Of Marital Status",fontsize=20)
ax.set_ylabel('Frequency',fontsize=20)
ax.set_title('PLOT 3-Subscription Based on Education Type',fontsize=22)
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(('university.degree', 'high.school','basic.9y','  professional.course','basic.4y','basic.6y', 'unknown','illiterate'),
                  fontsize = 12)
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
ax.legend((yes_bars,no_bars),('yes','no'),fontsize=17)

def autolabel(rects,fontsize=14):
    
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1*height,'%d' % int(height),
                ha='center', va='bottom',fontsize=fontsize)        
autolabel(yes_bars, 10)
autolabel(no_bars, 10)
plt.show()
print(yes_cc)
print(no_cc)
# Out:
# [165, 97, 43, 65, 38, 17, 26, 0]
# [1099, 824, 531, 470, 391, 211, 141, 1]

# %%
# 10) default vs target_subscribe

df = bank['default'].value_counts()
m_height = df.values.tolist() 
df.axes 
df_labels =df.axes[0].tolist() 

yes_cc = [] #yes Subscription list
no_cc = []    #no Subscription list
for x in df_labels:
    size = len(bank[bank['default'] == x].index)
    subs = len(bank[(bank['default'] == x) & (bank['target_subscribe'] == 'yes')].index)
    yes_cc.append(subs)
    no_cc.append(size-subs)
                        

ind = np.arange(3)  
width = 0.20
fig, ax = plt.subplots(figsize=(12,7))
yes_bars = ax.bar(ind, yes_cc , width, color='pink')
no_bars = ax.bar(ind+width, no_cc , width, color='purple')


ax.set_xlabel("Types Of Default Credit",fontsize=20)
ax.set_ylabel('Frequency',fontsize=20)
ax.set_title('PLOT 4-Subscription Based on Credit in Default',fontsize=22)
ax.set_xticks(ind + width / 2) 
ax.set_xticklabels(('no', ' unknown','yes'),
                  fontsize = 12)
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
ax.legend((yes_bars,no_bars),('yes','no'),fontsize=17)

def autolabel(rects,fontsize=14):
    
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1*height,'%d' % int(height),
                ha='center', va='bottom',fontsize=fontsize)        
autolabel(yes_bars, 10)
autolabel(no_bars, 10)
plt.show()
print(yes_cc)
print(no_cc)
# Out:
# [402, 49, 0]
# [2913, 754, 1]

# %%
# 11) housing vs target_subscribe

hg = bank['housing'].value_counts()
m_height = hg.values.tolist() 
hg.axes 
hg_labels = hg.axes[0].tolist() 

yes_cc = [] #yes Subscription list
no_cc = []    #no Subscription list
for x in hg_labels:
    size = len(bank[bank['housing'] == x].index)
    subs = len(bank[(bank['housing'] == x) & (bank['target_subscribe'] == 'yes')].index)
    yes_cc.append(subs)
    no_cc.append(size-subs)
                        

ind = np.arange(3) 
width = 0.20
fig, ax = plt.subplots(figsize=(12,7))
yes_bars = ax.bar(ind, yes_cc , width, color='yellow')
no_bars = ax.bar(ind+width, no_cc , width, color='orange')


ax.set_xlabel("Housing Loan Status",fontsize=20)
ax.set_ylabel('Frequency',fontsize=20)
ax.set_title('PLOT 5-Subscription Based on Housing Loan Status',fontsize=22)
ax.set_xticks(ind + width / 2) #Positioning on the x axis
ax.set_xticklabels(('yes', 'no','unknown'),
                  fontsize = 12)
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
ax.legend((yes_bars,no_bars),('yes','no'),fontsize=17)

def autolabel(rects,fontsize=14):
    
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1*height,'%d' % int(height),
                ha='center', va='bottom',fontsize=fontsize)        
autolabel(yes_bars, 10)
autolabel(no_bars, 10)
plt.show()
print(yes_cc)
print(no_cc)
# Out:
# [240, 202, 9]
# [1935, 1637, 96]

# %%
# 12) loan vs target_subscribe

loan = bank['loan'].value_counts()
m_height = hg.values.tolist() 
loan.axes
loan_labels = loan.axes[0].tolist() 

yes_cc = [] #yes Subscription list
no_cc = []    #no Subscription list
for x in loan_labels:
    size = len(bank[bank['loan'] == x].index)
    subs = len(bank[(bank['loan'] == x) & (bank['target_subscribe'] == 'yes')].index)
    yes_cc.append(subs)
    no_cc.append(size-subs)
                        

ind = np.arange(3)  
width = 0.20
fig, ax = plt.subplots(figsize=(12,7))
yes_bars = ax.bar(ind, yes_cc , width, color='green')
no_bars = ax.bar(ind+width, no_cc , width, color='#ADFF2F')


ax.set_xlabel("Personal Loan Status",fontsize=20)
ax.set_ylabel('Frequency',fontsize=20)
ax.set_title('PLOT 6-Subscription Based on Personal Loan Status',fontsize=22)
ax.set_xticks(ind + width / 2) 
ax.set_xticklabels(('no', 'yes','unknown'),
                  fontsize = 12)
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
ax.legend((yes_bars,no_bars),('yes','no'),fontsize=17)

def autolabel(rects,fontsize=14):
    
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1*height,'%d' % int(height),
                ha='center', va='bottom',fontsize=fontsize)        
autolabel(yes_bars, 10)
autolabel(no_bars, 10)
plt.show()
print(yes_cc)
print(no_cc)
# Out:
# [374, 68, 9]
# [2975, 597, 96]

# %%
# 13) contact vs target_subscribe

ct = bank['contact'].value_counts()
m_height = ct.values.tolist() 
ct.axes 
ct_labels = ct.axes[0].tolist() 

yes_cc = [] #yes Subscription list
no_cc = []    #no Subscription list
for x in ct_labels:
    size = len(bank[bank['contact'] == x].index)
    subs = len(bank[(bank['contact'] == x) & (bank['target_subscribe'] == 'yes')].index)
    yes_cc.append(subs)
    no_cc.append(size-subs)
                        

ind = np.arange(2)  
width = 0.10
fig, ax = plt.subplots(figsize=(12,7))
yes_bars = ax.bar(ind, yes_cc , width, color='cyan')
no_bars = ax.bar(ind+width, no_cc , width, color='blue')


ax.set_xlabel("Type Of Contact",fontsize=20)
ax.set_ylabel('Frequency',fontsize=20)
ax.set_title('PLOT 7-Subscription Based on Contact Type',fontsize=22)
ax.set_xticks(ind + width / 2) 
ax.set_xticklabels(('cellular', 'telephone'),
                  fontsize = 12)
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
ax.legend((yes_bars,no_bars),('yes','no'),fontsize=17)

def autolabel(rects,fontsize=14):
    
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1*height,'%d' % int(height),
                ha='center', va='bottom',fontsize=fontsize)        
autolabel(yes_bars, 10)
autolabel(no_bars, 10)
plt.show()
print(yes_cc)
print(no_cc)
# Out:
# [375, 76]
# [2277, 1391]

# %%
# 14) month vs target_subscribe

mt = bank['month'].value_counts()
m_height = mt.values.tolist()
mt.axes
mt_labels = mt.axes[0].tolist() 

yes_cc = [] #yes Subscription list
no_cc = []    #no Subscription list
for x in mt_labels:
    size = len(bank[bank['month'] == x].index)
    subs = len(bank[(bank['month'] == x) & (bank['target_subscribe'] == 'yes')].index)
    yes_cc.append(subs)
    no_cc.append(size-subs)
                        

ind = np.arange(10) 
width = 0.40
fig, ax = plt.subplots(figsize=(12,7))
yes_bars = ax.bar(ind, yes_cc , width, color='#ADFF2F')
no_bars = ax.bar(ind+width, no_cc , width, color='pink')


ax.set_xlabel("Month Of Last Contact",fontsize=20)
ax.set_ylabel('Frequency',fontsize=20)
ax.set_title('PLOT 8-Subscription Based on Month Of Last Contact',fontsize=22)
ax.set_xticks(ind + width / 2) 
ax.set_xticklabels(('May', 'July','August','June',' November','April','October','September','March','December'),
                  fontsize = 12)
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
ax.legend((yes_bars,no_bars),('yes','no'),fontsize=17)

def autolabel(rects,fontsize=14):
   
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1*height,'%d' % int(height),
                ha='center', va='bottom',fontsize=fontsize)        
autolabel(yes_bars, 10)
autolabel(no_bars, 10)
plt.show()
print(yes_cc)
print(no_cc)
# Out:
# [90, 59, 64, 68, 43, 36, 25, 26, 28, 12]
# [1288, 652, 572, 462, 403, 179, 44, 38, 20, 10]

# %%
# 15) day_of_week vs target_subscribe

dw = bank['day_of_week'].value_counts()
m_height = dw.values.tolist() 
dw.axes
dw_labels = dw.axes[0].tolist()

yes_cc = [] #yes Subscription list
no_cc = []    #no Subscription list
for x in dw_labels:
    size = len(bank[bank['day_of_week'] == x].index)
    subs = len(bank[(bank['day_of_week'] == x) & (bank['target_subscribe'] == 'yes')].index)
    yes_cc.append(subs)
    no_cc.append(size-subs)
                        

ind = np.arange(5) 
width = 0.30
fig, ax = plt.subplots(figsize=(12,7))
yes_bars = ax.bar(ind, yes_cc , width, color='yellow')
no_bars = ax.bar(ind+width, no_cc , width, color='#ADFF2F')


ax.set_xlabel("Day Of Last Contact",fontsize=20)
ax.set_ylabel('Frequency',fontsize=20)
ax.set_title('PLOT 9-Subscription Based on Day Of Last Contact',fontsize=22)
ax.set_xticks(ind + width / 2) 
ax.set_xticklabels(('Thursday', 'Monday','Tuesday','Wednesday','Friday'),
                  fontsize = 12)
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
ax.legend((yes_bars,no_bars),('yes','no'),fontsize=17)

def autolabel(rects,fontsize=14):
    
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1*height,'%d' % int(height),
                ha='center', va='bottom',fontsize=fontsize)        
autolabel(yes_bars, 10)
autolabel(no_bars, 10)
plt.show()
print(yes_cc)
print(no_cc)
# Out:
# [96, 98, 91, 83, 83]
# [764, 757, 750, 712, 685]

# %%
# 16) poutcome vs target_subscribe

ot = bank['poutcome'].value_counts()
m_height = ot.values.tolist() 
ot.axes 
ot_labels = ot.axes[0].tolist()
yes_cc = [] #yes Subscription list
no_cc = []    #no Subscription list
for x in ot_labels:
    size = len(bank[bank['poutcome'] == x].index)
    subs = len(bank[(bank['poutcome'] == x) & (bank['target_subscribe'] == 'yes')].index)
    yes_cc.append(subs)
    no_cc.append(size-subs)
                        

ind = np.arange(3) 
width = 0.20
fig, ax = plt.subplots(figsize=(12,7))
yes_bars = ax.bar(ind, yes_cc , width, color='#778899')
no_bars = ax.bar(ind+width, no_cc , width, color='#ADFF2F')


ax.set_xlabel("Outcome Of Last Contact",fontsize=20)
ax.set_ylabel('Frequency',fontsize=20)
ax.set_title('PLOT 10-Subscription Based on Outcome Of Last Contact',fontsize=22)
ax.set_xticks(ind + width / 2) 
ax.set_xticklabels(('nonexistent', 'failure','success'),
                  fontsize = 12)
for tick in ax.get_xticklabels():
    tick.set_rotation(90)
ax.legend((yes_bars,no_bars),('yes','no'),fontsize=17)

def autolabel(rects,fontsize=14):
   
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1*height,'%d' % int(height),
                ha='center', va='bottom',fontsize=fontsize)        
autolabel(yes_bars, 10)
autolabel(no_bars, 10)
plt.show()
print(yes_cc)
print(no_cc)
# Out:
# [292, 67, 92]
# [3231, 387, 50]

# %%
sns.pairplot(bank,vars = ["age","campaign","pdays","previous","emp.var.rate","cons.price.idx","cons.conf.idx","euribor3m","nr.employed"], hue = 'target_subscribe')
# Out:
# C:\ProgramData\Anaconda3\envs\py27\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
from sklearn import preprocessing
from sklearn.preprocessing import OrdinalEncoder

Data = bank.drop(columns ='target_subscribe').values
target = bank['target_subscribe']

target = preprocessing.LabelEncoder().fit_transform(target)
np.unique(target, return_counts = True)
Data = preprocessing.OrdinalEncoder().fit_transform(Data)
Data
# Out:
# array([[ 12.,   1.,   1., ...,   4., 156.,   6.],
#        [ 21.,   7.,   2., ...,  16., 207.,   8.],
#        [  7.,   7.,   1., ...,   8., 225.,  10.],
#        ...,
#        [  9.,   8.,   2., ...,   4., 160.,   6.],
#        [ 40.,   0.,   1., ...,  17., 229.,  10.],
#        [ 16.,   4.,   2., ...,   7., 199.,   9.]])

# %%
#Task 3: Data Modelling

##1) CLASSIFICATION :  
from sklearn.model_selection import train_test_split

## 50% for training and 50% for testing
X_train1, X_test1, Y_train1, Y_test1 = train_test_split(Data,target,test_size=0.50,random_state=999)
print X_train1.shape
print Y_train1.shape
print X_test1.shape
print Y_test1.shape

## 60% for training and 40% for testing
X_train2, X_test2, Y_train2, Y_test2 = train_test_split(Data,target,test_size=0.40,random_state=99)
print X_train2.shape
print Y_train2.shape
print X_test2.shape
print Y_test2.shape

## 80% for training and 20% for testing
X_train3, X_test3, Y_train3, Y_test3 = train_test_split(Data,target,test_size=0.20,random_state=999)
print X_train3.shape
print Y_train3.shape
print X_test3.shape
print Y_test3.shape
# Out:
# (2059L, 19L)
# (2059L,)
# (2060L, 19L)
# (2060L,)
# (2471L, 19L)
# (2471L,)
# (1648L, 19L)
# (1648L,)
# (3295L, 19L)
# (3295L,)
# (824L, 19L)
# (824L,)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score
from sklearn.model_selection import cross_val_score, RepeatedStratifiedKFold
import sklearn.metrics as metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn import preprocessing
from sklearn import feature_selection as fs
from sklearn.neighbors import KNeighborsClassifier

# %%
#finding value of k for k-nearest neighbor(on 50 : 50 split of data)
scores = []
for each in range(1,10):
    knn_n = KNeighborsClassifier(n_neighbors = each)
    knn_n.fit(X_train1,Y_train1)
    scores.append(knn_n.score(X_train1,Y_train1))
    
plt.plot(range(1,10),scores)
plt.title("k-value for 50-50 split")
plt.xlabel("k")
plt.ylabel("Accuracy")
plt.show()

# %%
#finding value of k for k-nearest neighbor(on 60 : 40 split of data)
scores = []
for each in range(1,10):
    knn_n = KNeighborsClassifier(n_neighbors = each)
    knn_n.fit(X_train2,Y_train2)
    scores.append(knn_n.score(X_train2,Y_train2))
    
plt.plot(range(1,10),scores)
plt.title("k-value for 60-40 split")
plt.xlabel("k")
plt.ylabel("Accuracy")
plt.show()

# %%
#finding value of k for k-nearest neighbor(on 80 : 20 split of data)
scores = []
for each in range(1,10):
    knn_n = KNeighborsClassifier(n_neighbors = each)
    knn_n.fit(X_train3,Y_train3)
    scores.append(knn_n.score(X_train3,Y_train3))
    
plt.plot(range(1,10),scores)
plt.title("k-value for 80-20 split")
plt.xlabel("k")
plt.ylabel("Accuracy")
plt.show()

# %%
#Feature Selection for K-nearest neighbour algorithm
num_features = 5
model_rfi = RandomForestClassifier(n_estimators=100)
model_rfi.fit(Data, target)
fs_indices_rfi = np.argsort(model_rfi.feature_importances_)[::-1][0:num_features]

best_features_rfi = bank.columns[fs_indices_rfi].values
best_features_rfi

feature_importances_rfi = model_rfi.feature_importances_[fs_indices_rfi]
feature_importances_rfi

y_pos = np.arange(len(best_features_rfi))
plt.bar(y_pos, feature_importances_rfi, align='center', alpha=0.5)
plt.xticks(y_pos, best_features_rfi, rotation = 90)
plt.ylabel('Importance')
plt.title('Random forest: Selected important feature')
plt.show()

# %%
#K-Nearest Neighbour alogorithm on 50 : 50 split of data
knn_classifier = KNeighborsClassifier(n_neighbors=3, p=2)
fit1 = knn_classifier.fit(X_train1, Y_train1);
knn_50_50 = knn_classifier.score(X=X_test1, y=Y_test1)

predicted1 = fit1.predict(X_test1)
cm = confusion_matrix(Y_test1, predicted1)

f, ax = plt.subplots(figsize =(4,4))
sns.heatmap(cm,annot = True,linewidths=0.5,linecolor="black",fmt = ".0f",ax=ax)
plt.title("PLOT 1-Confusion Matrix 50-50 split")
plt.xlabel("Predicted y values")
plt.ylabel("Real y values")
plt.show()

print("Precision: ", precision_score(Y_test1, predicted1))
print("Recall: ", recall_score(Y_test1, predicted1))
print("F1-score: ",f1_score(Y_test1, predicted1))
print("Classification Accuracy: ",metrics.accuracy_score(Y_test1, predicted1))
print("Classification Error: ", 1 - metrics.accuracy_score(Y_test1, predicted1))
# Out:
# ('Precision: ', 0.4233576642335766)
# ('Recall: ', 0.2510822510822511)
# ('F1-score: ', 0.3152173913043478)
# ('Classification Accuracy: ', 0.8776699029126214)
# ('Classification Error: ', 0.12233009708737863)

# %%
#K-Nearest Neighbour alogorithm on 50 : 50 split of data
#Performance with Full Set of Features

clf = KNeighborsClassifier(n_neighbors=3)
cv_method = RepeatedStratifiedKFold(n_splits=5, 
                                     n_repeats=3,
                                     random_state=999)
scoring_metric = 'accuracy'
cv_results_full = cross_val_score(estimator=clf,
                             X=X_test1,
                             y=Y_test1, 
                             cv=cv_method, 
                             scoring=scoring_metric)
print cv_results_full
print cv_results_full.mean().round(3)

#performance with selected features

cv_results_rfi = cross_val_score(estimator=clf,
                             X=X_test1[:, fs_indices_rfi],
                             y=Y_test1, 
                             cv=cv_method, 
                             scoring=scoring_metric)
print cv_results_rfi
F_knn_50_50 = cv_results_rfi.mean().round(3)
print F_knn_50_50
# Out:
# [0.87409201 0.87864078 0.88834951 0.8907767  0.8783455  0.88377724
#  0.87621359 0.88349515 0.87378641 0.87591241 0.89104116 0.88106796
#  0.8907767  0.8907767  0.86861314]
# 0.882
# [0.84745763 0.86893204 0.8907767  0.89805825 0.88321168 0.87893462
#  0.87378641 0.88106796 0.88106796 0.88564477 0.86682809 0.87135922
#  0.88834951 0.87621359 0.88321168]
# 0.878

# %%
#K-Nearest Neighbour alogorithm on 60 : 40 split of data
knn_classifier = KNeighborsClassifier(n_neighbors=3, p=2)
fit2 = knn_classifier.fit(X_train2, Y_train2);
knn_60_40 = knn_classifier.score(X=X_test2, y=Y_test2)

predicted2 = fit2.predict(X_test2)
cm = confusion_matrix(Y_test2, predicted2)

f, ax = plt.subplots(figsize =(4,4))
sns.heatmap(cm,annot = True,linewidths=0.5,linecolor="black",fmt = ".0f",ax=ax)
plt.title("PLOT 2-Confusion Matrix 60-40 split")
plt.xlabel("Predicted y values")
plt.ylabel("Real y values")
plt.show()

print("Precision: ", precision_score(Y_test2, predicted2))
print("Recall: ", recall_score(Y_test2, predicted2))
print("F1-score: ",f1_score(Y_test2, predicted2))
print("Classification Accuracy: ",metrics.accuracy_score(Y_test2, predicted2))
print("Classification Error: ", 1 - metrics.accuracy_score(Y_test2, predicted2))
# Out:
# ('Precision: ', 0.4803921568627451)
# ('Recall: ', 0.26063829787234044)
# ('F1-score: ', 0.33793103448275863)
# ('Classification Accuracy: ', 0.883495145631068)
# ('Classification Error: ', 0.11650485436893199)

# %%
#K-Nearest Neighbour alogorithm on 60 : 40 split of data
#Performance with Full Set of Features

clf = KNeighborsClassifier(n_neighbors=3)
cv_method = RepeatedStratifiedKFold(n_splits=5, 
                                     n_repeats=3,
                                     random_state=999)
scoring_metric = 'accuracy'
cv_results_full = cross_val_score(estimator=clf,
                             X=X_test2,
                             y=Y_test2, 
                             cv=cv_method, 
                             scoring=scoring_metric)
print cv_results_full
print cv_results_full.mean().round(3)

#performance with selected features

cv_results_rfi = cross_val_score(estimator=clf,
                             X=X_test2[:, fs_indices_rfi],
                             y=Y_test2, 
                             cv=cv_method, 
                             scoring=scoring_metric)
print cv_results_rfi
F_knn_60_40 = cv_results_rfi.mean().round(3)
print F_knn_60_40
# Out:
# [0.89090909 0.86969697 0.87575758 0.87537994 0.88449848 0.87272727
#  0.88484848 0.88787879 0.88449848 0.89361702 0.9030303  0.87575758
#  0.88787879 0.89057751 0.8662614 ]
# 0.883
# [0.88181818 0.87878788 0.86666667 0.86322188 0.88145897 0.87878788
#  0.88484848 0.86969697 0.89057751 0.87537994 0.88787879 0.87272727
#  0.89090909 0.89665653 0.8662614 ]
# 0.879

# %%
#K-Nearest Neighbour alogorithm on 80 : 20 split of data
knn_classifier = KNeighborsClassifier(n_neighbors=3, p=2)
fit3 = knn_classifier.fit(X_train3, Y_train3);
knn_80_20 = knn_classifier.score(X=X_test3, y=Y_test3)

predicted3 = fit3.predict(X_test3)
cm = confusion_matrix(Y_test3, predicted3)

f, ax = plt.subplots(figsize =(4,4))
sns.heatmap(cm,annot = True,linewidths=0.5,linecolor="black",fmt = ".0f",ax=ax)
plt.title("PLOT 3-Confusion Matrix 80-20 split")
plt.xlabel("Predicted y values")
plt.ylabel("Real y values")
plt.show()

print("Precision: ", precision_score(Y_test3, predicted3))
print("Recall: ", recall_score(Y_test3, predicted3))
print("F1-score: ",f1_score(Y_test3, predicted3))
print("Classification Accuracy: ",metrics.accuracy_score(Y_test3, predicted3))
print("Classification Error: ", 1 - metrics.accuracy_score(Y_test3, predicted3))
# Out:
# ('Precision: ', 0.5166666666666667)
# ('Recall: ', 0.31)
# ('F1-score: ', 0.3875)
# ('Classification Accuracy: ', 0.8810679611650486)
# ('Classification Error: ', 0.1189320388349514)

# %%
#K-Nearest Neighbour alogorithm on 80 : 20 split of data
#Performance with Full Set of Features

clf = KNeighborsClassifier(n_neighbors=3)
cv_method = RepeatedStratifiedKFold(n_splits=5, 
                                     n_repeats=3,
                                     random_state=999)
scoring_metric = 'accuracy'
cv_results_full = cross_val_score(estimator=clf,
                             X=X_test3,
                             y=Y_test3, 
                             cv=cv_method, 
                             scoring=scoring_metric)
print cv_results_full
print cv_results_full.mean().round(3)

#performance with selected features

cv_results_rfi = cross_val_score(estimator=clf,
                             X=X_test3[:, fs_indices_rfi],
                             y=Y_test3, 
                             cv=cv_method, 
                             scoring=scoring_metric)
print cv_results_rfi
F_knn_80_20 = cv_results_rfi.mean().round(3)
print F_knn_80_20
# Out:
# [0.87878788 0.87878788 0.88484848 0.86060606 0.8597561  0.86666667
#  0.88484848 0.87878788 0.86060606 0.86585366 0.9030303  0.86666667
#  0.87272727 0.83030303 0.88414634]
# 0.872
# [0.84848485 0.87272727 0.87272727 0.81212121 0.89634146 0.84848485
#  0.84848485 0.84242424 0.85454545 0.84756098 0.86666667 0.86060606
#  0.86666667 0.84242424 0.87804878]
# 0.857

# %%
#Decision Tree alogorithm on 50 : 50 split of data
from sklearn.tree import DecisionTreeClassifier

dt_classifier = DecisionTreeClassifier(max_depth=2,
                                       criterion='gini',
                                       random_state = 0)
fit4 = dt_classifier.fit(X_train1, Y_train1);
dtree_50_50 = dt_classifier.score(X_test1, Y_test1)

predicted4 = fit4.predict(X_test1)
cm = confusion_matrix(Y_test1, predicted4)

f, ax = plt.subplots(figsize =(4,4))
sns.heatmap(cm,annot = True,linewidths=0.5,linecolor="black",fmt = ".0f",ax=ax)
plt.title("PLOT 4-Confusion Matrix 50-50 split")
plt.xlabel("Predicted y values")
plt.ylabel("Real y values")
plt.show()

print("Precision: ", precision_score(Y_test1, predicted4))
print("Recall: ", recall_score(Y_test1, predicted4))
print("F1-score: ",f1_score(Y_test1, predicted4))
print("Classification Accuracy: ",metrics.accuracy_score(Y_test1, predicted4))
print("Classification Error: ", 1 - metrics.accuracy_score(Y_test1, predicted4))
# Out:
# ('Precision: ', 0.6949152542372882)
# ('Recall: ', 0.1774891774891775)
# ('F1-score: ', 0.2827586206896552)
# ('Classification Accuracy: ', 0.8990291262135922)
# ('Classification Error: ', 0.10097087378640779)

# %%
#Decision Tree alogorithm on 60 : 40 split of data
dt_classifier = DecisionTreeClassifier(max_depth=3,
                                       criterion='gini',
                                       random_state = 0)
fit5 = dt_classifier.fit(X_train2, Y_train2);
dtree_60_40 = dt_classifier.score(X_test2, Y_test2)

predicted5 = fit5.predict(X_test2)
cm = confusion_matrix(Y_test2, predicted5)

f, ax = plt.subplots(figsize =(4,4))
sns.heatmap(cm,annot = True,linewidths=0.5,linecolor="black",fmt = ".0f",ax=ax)
plt.title("PLOT 5-Confusion Matrix 60-40 split")
plt.xlabel("Predicted y values")
plt.ylabel("Real y values")
plt.show()

print("Precision: ", precision_score(Y_test2, predicted5))
print("Recall: ", recall_score(Y_test2, predicted5))
print("F1-score: ",f1_score(Y_test2, predicted5))
print("Classification Accuracy: ",metrics.accuracy_score(Y_test2, predicted5))
print("Classification Error: ", 1 - metrics.accuracy_score(Y_test2, predicted5))
# Out:
# ('Precision: ', 0.578125)
# ('Recall: ', 0.19680851063829788)
# ('F1-score: ', 0.29365079365079366)
# ('Classification Accuracy: ', 0.8919902912621359)
# ('Classification Error: ', 0.10800970873786409)

# %%
#Decision Tree alogorithm on 80 : 20 split of data
from sklearn.tree import DecisionTreeClassifier

dt_classifier = DecisionTreeClassifier(max_depth=3,
                                       criterion='gini',
                                       random_state = 0)
fit6 = dt_classifier.fit(X_train3, Y_train3);
dtree_80_20 = dt_classifier.score(X_test3, Y_test3)

predicted6 = fit6.predict(X_test3)
cm = confusion_matrix(Y_test3, predicted6)

f, ax = plt.subplots(figsize =(4,4))
sns.heatmap(cm,annot = True,linewidths=0.5,linecolor="black",fmt = ".0f",ax=ax)
plt.title("PLOT 6-Confusion Matrix 80-20 split")
plt.xlabel("Predicted y values")
plt.ylabel("Real y values")
plt.show()

print("Precision: ", precision_score(Y_test3, predicted6))
print("Recall: ", recall_score(Y_test3, predicted6))
print("F1-score: ",f1_score(Y_test3, predicted6))
print("Classification Accuracy: ",metrics.accuracy_score(Y_test3, predicted6))
print("Classification Error: ", 1 - metrics.accuracy_score(Y_test3, predicted6))
# Out:
# ('Precision: ', 0.7586206896551724)
# ('Recall: ', 0.22)
# ('F1-score: ', 0.34108527131782945)
# ('Classification Accuracy: ', 0.8968446601941747)
# ('Classification Error: ', 0.10315533980582525)

# %%
## Comparison of KNeighborsClassifier and DecisionTreeClassifier
import matplotlib.pyplot as plt
DTree = [dtree_50_50,dtree_60_40, dtree_80_20]
KNn = [knn_50_50,knn_60_40,knn_80_20]
F_KNn = [F_knn_50_50, F_knn_60_40, F_knn_80_20]


line_chart1 = plt.plot(DTree)
line_chart2 = plt.plot(KNn)
line_chart3 = plt.plot(F_KNn)
plt.title('Comaparison of Algorithms')
plt.xticks([])
plt.xticks(np.arange(3), ('50:50','60:40','80:20'))
plt.xlabel('Data Split')
plt.ylabel('Accuracy Score')
plt.legend(['Decision Tree', 'K-NN', 'Selected Feature K-NN'], loc=4)
plt.show()

# %%
DTree = [dtree_50_50,dtree_60_40, dtree_80_20]
KNn = [knn_50_50,knn_60_40,knn_80_20]
F_KNn = [F_knn_50_50, F_knn_60_40, F_knn_80_20]


line_chart1 = plt.plot(DTree)
line_chart2 = plt.plot(KNn)
line_chart3 = plt.plot(F_KNn)
plt.title('Comaparison of Algorithms')
plt.xticks([])
plt.xticks(np.arange(3), ('50:50','60:40','80:20'))
plt.xlabel('Data Split')
plt.ylabel('Accuracy Score')
plt.legend(['Decision Tree', 'K-NN', 'Selected Feature K-NN'], loc=4)
plt.show()
